# %%
# variable:

# %%
# input () to take input from end user

# %%
name = input("Enter name: ")
location = input("Enter your location: ")
age = input("Enter your age: ")
# Out:
# Enter name: rahul
# Enter your location: Delhi
# Enter your age: 20

# %%
print(name)
print(location)
print(age)
# Out:
# rahul
# Delhi
# 20

# %%
type(age)
# Out:
# str

# %%
age = int(input("Enter your age: "))
# Out:
# Enter your age: rahul
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 age = int(input("Enter your age: "))
#
# ValueError: invalid literal for int() with base 10: 'rahul'

# %%
type(age)
# Out:
# int

# %%
#list

# %%
info = ['sadhna', 20, 6.7, 8<5]
info
# Out:
# ['sadhna', 20, 6.7, False]

# %%
info.clear()

# %%
info
# Out:
# []

# %%
type(info)
# Out:
# list

# %%
info = ['sadhna', 20, 6.7, 8<5]

# %%
copy_of_info = info.copy()

# %%
copy_of_info
# Out:
# ['sadhna', 20, 6.7, False]

# %%
info.count('sadhna')
# Out:
# 1

# %%
info.count('Sadhna')
# Out:
# 0

# %%
info.index('sadhna')
# Out:
# 0

# %%
info.index(20)
# Out:
# 1

# %%
info.pop()
# Out:
# False

# %%
info
# Out:
# ['sadhna', 20, 6.7]

# %%
info.pop(2)
# Out:
# 6.7

# %%
info
# Out:
# ['sadhna', 20]

# %%
info.extend(['test','python',45,23])

# %%
info
# Out:
# ['sadhna', 20, 'test', 'python', 45, 23]

# %%
info.remove(45)

# %%
info
# Out:
# ['sadhna', 20, 'test', 'python', 23]

# %%
info.reverse()

# %%
info
# Out:
# [23, 'python', 'test', 20, 'sadhna']

# %%
info.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 info.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l1 = [87656,865,4567,86]

# %%
l1.sort()

# %%
l1
# Out:
# [86, 865, 4567, 87656]

# %%
l2 = ['jhg','re','a']

# %%
l2.sort()
l2
# Out:
# ['a', 'jhg', 're']

# %%
l2.

# %%
# list [] its mutable can do read/write both
# append() add one value
# extend([]) it adds list in existing list
# index() find the position of value in list
# insert() add position wise element
# copy() make a copy of list
# clear() empty the list
# pop() bydefault remove last element and work position wise removing of value
# remove() remove any value from the list
# sort() to sort similar data type list
# count() frequency of value in the list
# reverse () change the order of list

# %%
# tuple () # read only immutable

# %%
t1 = ('python', 78,3.6,'jh')
t1
# Out:
# ('python', 78, 3.6, 'jh')

# %%
type(t1)
# Out:
# tuple

# %%
t1.count('python')
# Out:
# 1

# %%
t1.index('python')
# Out:
# 0

# %%
info
# Out:
# [23, 'python', 'test', 20, 'sadhna']

# %%
info.index(23)
# Out:
# 0

# %%
# indexing/position it starts from 0

# %%
info[1]
# Out:
# 'python'

# %%
info[1:4] # in indexing last range is excluded
# Out:
# ['python', 'test', 20]

# %%
info[:2] #
# Out:
# [23, 'python']

# %%
info[2:]
# Out:
# ['test', 20, 'sadhna']

# %%
st = ['rohan','delhi',20,'170 cm']

# %%
st
# Out:
# ['rohan', 'delhi', 20, '170 cm']

# %%
st[0]
# Out:
# 'rohan'

# %%
# dict {'key':'value'}

# %%
student_info = {'name':'rohan','location':'delhi','age':20,'height':'170 cm'}

# %%
student_info
# Out:
# {'name': 'rohan', 'location': 'delhi', 'age': 20, 'height': '170 cm'}

# %%
student_info['name']
# Out:
# 'rohan'

# %%
len(student_info)
# Out:
# 4

# %%
student_info.keys()
# Out:
# dict_keys(['name', 'location', 'age', 'height'])

# %%
student_info.values()
# Out:
# dict_values(['rohan', 'delhi', 20, '170 cm'])

# %%
student_info.items()
# Out:
# dict_items([('name', 'rohan'), ('location', 'delhi'), ('age', 20), ('height', '170 cm')])

# %%
student_info['age']=25

# %%
student_info
# Out:
# {'name': 'rohan', 'location': 'delhi', 'age': 25, 'height': '170 cm'}

# %%
len(info)
# Out:
# 5

# %%
info
# Out:
# [23, 'python', 'test', 20, 'sadhna']

# %%
len(t1)
# Out:
# 4

# %%
t1
# Out:
# ('python', 78, 3.6, 'jh')

# %%
len(student_info)
# Out:
# 4

# %%
s1 = 'i like python'
len(s1)
# Out:
# 13

# %%
s1[0]
# Out:
# 'i'

# %%
s1[0:10]
# Out:
# 'i like pyt'

# %%
info
# Out:
# [23, 'python', 'test', 20, 'sadhna']

# %%
t1
# Out:
# ('python', 78, 3.6, 'jh')

# %%
t1[0]
# Out:
# 'python'

# %%
t1[2:]
# Out:
# (3.6, 'jh')

# %%
s1
# Out:
# 'i like python'

# %%
student_info
# Out:
# {'name': 'rohan', 'location': 'delhi', 'age': 25, 'height': '170 cm'}

# %%
student_info.get('name')
# Out:
# 'rohan'

# %%
student_info['name']
# Out:
# 'rohan'

# %%
student_info['roll_no']=2

# %%
student_info
# Out:
# {'name': 'rohan',
#  'location': 'delhi',
#  'age': 25,
#  'height': '170 cm',
#  'roll_no': 2}

# %%
'location' in student_info
# Out:
# True

# %%
student_info = student_info.fromkeys(['marks']),30

# %%
student_info
# Out:
# ({'marks': None}, 30)

# %%
# some nested dictionary examples to understand more
student = {
    "name": "Alice",
    "age": 22,
    "courses": {
        "math": {"grade": "A", "credits": 3},
        "science": {"grade": "B", "credits": 4}
    }
}
student
# Out:
# {'name': 'Alice',
#  'age': 22,
#  'courses': {'math': {'grade': 'A', 'credits': 3},
#   'science': {'grade': 'B', 'credits': 4}}}

# %%
student["courses"]
# Out:
# {'math': {'grade': 'A', 'credits': 3}, 'science': {'grade': 'B', 'credits': 4}}

# %%
student["courses"]['math']['grade']
# Out:
# 'A'

# %%
student_info = {'name':'rohan','location':'delhi','age':20,'height':'170 cm'}

# %%
student_info['marks'] = 30

# %%
student_info
# Out:
# {'name': 'rohan',
#  'location': 'delhi',
#  'age': 20,
#  'height': '170 cm',
#  'marks': 30}

# %%
student['courses'].keys()
# Out:
# dict_keys(['math', 'science'])

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'courses'])

# %%
student_info
# Out:
# {'name': 'rohan',
#  'location': 'delhi',
#  'age': 20,
#  'height': '170 cm',
#  'marks': 30}

# %%
student_info.update({'gender':'male','score':80})

# %%
student_info
# Out:
# {'name': 'rohan',
#  'location': 'delhi',
#  'age': 20,
#  'height': '170 cm',
#  'marks': 30,
#  'gender': 'male',
#  'score': 80}

# %%
# list []
# tuple ()
# dict {'key':'value'}
# set {}

# %%
numbers = {1, 2,3,3,8,6,4, 4, 5} # sets automatically remove duplicates
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
s1 = {'a','z','b','b','c','c'}
new_s1 = list(s1)

# %%
new_s1.sort()

# %%
new_s1
# Out:
# ['a', 'b', 'c', 'z']

# %%
new_set = {1,2,'a','b',10} 
new_set
# Out:
# {1, 10, 2, 'a', 'b'}

# %%
print(new_set)
# Out:
# {1, 2, 'b', 10, 'a'}

# %%
new_set[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 new_set[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1
# Out:
# {'a', 'b', 'c', 'z'}

# %%
test = " i like code in python".strip() # remove leading and trailing spaces

# %%
test.capitalize()
# Out:
# 'I like code in python'

# %%
test1 = 'python class'.capitalize()

# %%
test1.upper()
# Out:
# 'PYTHON CLASS'

# %%
test1.lower()
# Out:
# 'python class'

# %%
test1.title()
# Out:
# 'Python Class'

# %%
# take input from student and prinrt a string with student name, age, location

# %%
st_name = input("Enter name in lower case").strip().capitalize()
st_name
# Out:
# Enter name in lower case    rohan
# 'Rohan'

# %%
len(st_name)
# Out:
# 5

# %%
st_name
# Out:
# 'Rohan'

# %%
st_name1 = input("Enter name in lower case").capitalize().strip()
st_name1
# Out:
# Enter name in lower case      rohan
# 'rohan'

# %%
st_name1 = input("Enter name in lower case").lower().strip()

# %%
# take 2 numbers from end user and add those
num1 = int(input("enter number 1: "))
num2 = int(input("enter number 2: "))
addition_num = num1 + num2
#print("the sum is", num1 + num2)
# Out:
# enter number 1: 6
# enter number 2: 8

# %%
"The sum of {} and {} is {}".format(num1, num2, addition_num)
# Out:
# 'The sum of 6 and 8 is 14'

# %%
# student_info which takes student info and print all the in fo in one string

# %%
name = str(input("Enter the name of student : "))
course = str(input("Enter the course : "))
duration = int(input("Enter the duration : "))
print("{} is attending the {} course for {} months".format(name,course,duration))
# Out:
# Enter the name of student : amsa
# Enter the course : agentic
# Enter the duration : 5
# amsa is attending the agentic course for 5 months

# %%
name = input("Enter student's name: ")
age = input("Enter student's age: ")
grade = input("Enter student's grade: ")

# Format and return the information as a single string
student_info = f"Student Name: {name}, Age: {age}, Grade: {grade}"
print(student_info)
# Out:
# Enter student's name: deepak
# Enter student's age: 20
# Enter student's grade: btech
# Student Name: deepak, Age: 20, Grade: btech

# %%
name = input('Enter student name: ')
rollno = int(input('Enter rollno: '))
location = input('Enter location: ')
avg_score = input('Enter avg score: ')
print("The details of ",name," are as follows : ","Roll no: ",rollno, "Location: ",location,"Avg Score: ",avg_score)
# Out:
# Enter student name: manish
# Enter rollno: 56
# Enter location: noida
# Enter avg score: 60
# The details of  manish  are as follows :  Roll no:  56 Location:  noida Avg Score:  60

# %%
st_name= input("enter name")
st_age= int(input("enter age"))
marks= int(input("enter marks"))

print("student data is {} age is {} and marks is {}".format(st_name,st_age,marks))
# Out:
# enter name6
# enter age7
# enter marks7
# student data is 6 age is 7 and marks is 7
